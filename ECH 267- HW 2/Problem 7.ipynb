# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,1,100)
y1=x**2
y2=x**3

plt.plot(x,y1, label='$x_{2}$=$x_1^2$')
plt.plot(x,y2, label='$x_{2}$=$x_1^3$')
plt.xlabel('$x_{1}$')
plt.ylabel('$x_{2}$')
plt.legend(loc='best')
plt.savefig('7')
plt.show()
